# %%
import pandas as pd

df_purprod = pd.read_csv('../../LMEMBERS/data/purprod2.csv',encoding='cp949')

# %%
df_purprod
# Out:
#          제휴사    영수증번호    소분류코드    소분류명    통합분류 소비재분류   고객번호  점포코드      구매일자  \
# 0          A  1416069  A080106    명품잡화  명품/쥬얼리   전문품  14323     6  20140221
# 1          A  1500785  A080106    명품잡화  명품/쥬얼리   전문품  14323     6  20140307
# 2          A  1677262  A080106    명품잡화  명품/쥬얼리   전문품  14323     6  20140405
# 3          A  4593637  A080110    디자이너  명품/쥬얼리   전문품  13376     1  20150627
# 4          A  4573361  A080107  명품잡화보석  명품/쥬얼리   전문품   2290     1  20150624
# ...       ..      ...      ...     ...     ...   ...    ...   ...       ...
# 28545420   C  8648886  C120601  공병/공박스      기타   편의품   6286   282  20150131
# 28545421   C  8924449  C120601  공병/공박스      기타   편의품   1955   285  20150120
# 28545422   B  8839010  B050203      당근     식료품   편의품  17782    47  20140106
# 28545423   A  3726160  A010904      공병     기호품   편의품   6454     4  20150217
# 28545424   C   462175  C030109      깻잎     식료품   편의품  12552    11  20141025
#
#           구매시간       구매금액  YEAR   월
# 0           14  101330000  2014   2
# 1           14  101110000  2014   3
# 2           16   99960000  2014   4
# 3           16   87769260  2015   6
# 4           13   74410000  2015   6
# ...        ...        ...   ...  ..
# 28545420    18         40  2015   1
# 28545421    21         40  2015   1
# 28545422    19         38  2014   1
# 28545423    14         30  2015   2
# 28545424    20         30  2014  10
#
# [28545425 rows x 13 columns]

# %%
df_prodcl2 = pd.read_csv('../../LMEMBERS/data/prodcl2.csv')

# %%
df_prodcl2
# Out:
#      제휴사  대분류코드  중분류코드    소분류코드    중분류명      소분류명     통합분류 소비재분류
# 0      A      1    101  A010101    일용잡화      위생세제     생활잡화   편의품
# 1      A      1    101  A010102    일용잡화       휴지류     생활잡화   편의품
# 2      A      1    101  A010103    일용잡화      뷰티상품  패션의류/잡화   편의품
# 3      A      1    101  A010104    일용잡화      일용잡화     생활잡화   편의품
# 4      A      1    101  A010105    일용잡화      세트상품     생활잡화   편의품
# ...   ..    ...    ...      ...     ...       ...      ...   ...
# 4381   D      8    802  D080204  아이메이크업     아이섀도우  패션의류/잡화   편의품
# 4382   D      8    802  D080205  아이메이크업    메이크업세트  패션의류/잡화   편의품
# 4383   D      8    803  D080301   립메이크업  립스틱/립라이너  패션의류/잡화   편의품
# 4384   D      8    803  D080302   립메이크업   립글로즈/틴트  패션의류/잡화   편의품
# 4385   D      8    804  D080401  네일메이크업  일반네일/케어류  패션의류/잡화   편의품
#
# [4386 rows x 8 columns]

# %%
# Out:
# 150779665853
