# %%
import os
import sys
import urllib.request
client_id = "Xm1WkS4jX4BHrHrIYVwb"
client_secret = "Mo1eRhZvLT"
encText = urllib.parse.quote("빅데이터")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Fri, 11 Feb 2022 15:48:18 +0900",
# "total": 1018973,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>빅데이터</b>학원 기초과정부터 배워요",
# "link": "https:\/\/blog.naver.com\/ssohi07?Redirect=Log&logNo=222638093778",
# "description": "특히 데이터를 수집하여 통계를 작성하고 이를 통해 다양한 일을 할 수 있는 분야가 유망했습니다. 저는 이 분야가 마음에 들어서 <b>빅데이터</b>학원을 등록하게 되었습니다. <b>빅데이터</b> 분야는 앞으로도 전망이... ",
# "bloggername": "너와 wedding의 연결고리",
# "bloggerlink": "https://blog.naver.com/ssohi07",
# "postdate": "20220203"
#
# },
# {
# "title": "<b>빅데이터</b>분석기사인강 통한 시험 준비로 필기 합격 기대!",
# "link": "https:\/\/blog.naver.com\/waiting25?Redirect=Log&logNo=222641084425",
# "description": "<b>빅데이터</b>분석기사는 자료(데이터) 경제 활성화에 따라 대량의 정형. 비정형 자료를 분석, 미례를 예측하고 최적화 모형을 제시하는 실무자로서 전 세계적으로 <b>빅데이터</b>가 미래성장동력으로 인식되어져가고... ",
# "bloggername": "스터디채널 공식블로그",
# "bloggerlink": "https://blog.naver.com/waiting25",
# "postdate": "20220207"
#
# },
# {
# "title": "<b>빅데이터</b>학원 실기 위주의 학습",
# ...

# %%
# 네이버 검색 API예제는 블로그를 비롯 전문자료까지 호출방법이 동일하므로 blog검색만 대표로 예제를 올렸습니다.
# 네이버 검색 Open API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "Xm1WkS4jX4BHrHrIYVwb"
client_secret = "Mo1eRhZvLT"

encText = urllib.parse.quote("빅데이터")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# "lastBuildDate": "Fri, 11 Feb 2022 15:48:06 +0900",
# "total": 1018973,
# "start": 2,
# "display": 10,
# "items": [
# {
# "title": "<b>빅데이터</b>분석기사인강 통한 시험 준비로 필기 합격 기대!",
# "link": "https:\/\/blog.naver.com\/waiting25?Redirect=Log&logNo=222641084425",
# "description": "<b>빅데이터</b>분석기사는 자료(데이터) 경제 활성화에 따라 대량의 정형. 비정형 자료를 분석, 미례를 예측하고 최적화 모형을 제시하는 실무자로서 전 세계적으로 <b>빅데이터</b>가 미래성장동력으로 인식되어져가고... ",
# "bloggername": "스터디채널 공식블로그",
# "bloggerlink": "https://blog.naver.com/waiting25",
# "postdate": "20220207"
#
# },
# {
# "title": "<b>빅데이터</b>학원 실기 위주의 학습",
# "link": "https:\/\/blog.naver.com\/blackhole68?Redirect=Log&logNo=222596181315",
# "description": "<b>빅데이터</b>는 말 그대로 방대한 양의 데이터 양을 말하는건데, 갈수록 정보통신 기술이 발전하고, 사용자가 많아 지기 때문에 갈수록 <b>빅데이터</b>에 의존하는 기업이 많아지는 만큼 장래성이 밝다고 느껴져서... ",
# "bloggername": "김용식 문학서재",
# "bloggerlink": "https://blog.naver.com/blackhole68",
# "postdate": "20211215"
#
# },
# {
# "title": "<b>빅데이터</b>전문가자격증 공부 순서는 이렇게!",
# ...

# %%
json.loads(response_body.decode('utf-8'))['items']
# Out:
# [{'title': '<b>빅데이터</b>학원 기초과정부터 배워요',
#   'link': 'https://blog.naver.com/ssohi07?Redirect=Log&logNo=222638093778',
#   'description': '특히 데이터를 수집하여 통계를 작성하고 이를 통해 다양한 일을 할 수 있는 분야가 유망했습니다. 저는 이 분야가 마음에 들어서 <b>빅데이터</b>학원을 등록하게 되었습니다. <b>빅데이터</b> 분야는 앞으로도 전망이... ',
#   'bloggername': '너와 wedding의 연결고리',
#   'bloggerlink': 'https://blog.naver.com/ssohi07',
#   'postdate': '20220203'},
#  {'title': '<b>빅데이터</b>분석기사인강 통한 시험 준비로 필기 합격 기대!',
#   'link': 'https://blog.naver.com/waiting25?Redirect=Log&logNo=222641084425',
#   'description': '<b>빅데이터</b>분석기사는 자료(데이터) 경제 활성화에 따라 대량의 정형. 비정형 자료를 분석, 미례를 예측하고 최적화 모형을 제시하는 실무자로서 전 세계적으로 <b>빅데이터</b>가 미래성장동력으로 인식되어져가고... ',
#   'bloggername': '스터디채널 공식블로그',
#   'bloggerlink': 'https://blog.naver.com/waiting25',
#   'postdate': '20220207'},
#  {'title': '<b>빅데이터</b>학원 실기 위주의 학습',
#   'link': 'https://blog.naver.com/blackhole68?Redirect=Log&logNo=222596181315',
# ...

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "Xm1WkS4jX4BHrHrIYVwb"
client_secret = "Mo1eRhZvLT"
# encText = urllib.parse.quote("빅데이터")
query = urllib.parse.quote(input("검색할 단어 : "))

idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns = ['Title','Link','Description'])

for start_index in range(start,end,display):
    url = "https://openapi.naver.com/v1/search/blog?query=" + query \
    + '&display=' + str(display) \
    + '&start=' + str(start_index)
    
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0, len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,'', items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag,'',items[item_index]['description'])
            web_df.loc[idx] = [title,link,description]
            idx += 1
           
    else:
        print("Error Code:" + rescode)
web_df
# Out:
# 검색할 단어 : ai
#                                             Title  \
# 0    CES 2022 AI 메타버스 그린 ICT 기술과 ESG 담은 SK텔레콤...
# 1                           홈트앱 AI로 즐기는 운동 어플 하우핏
# 2                    루미나르ai 왜 쓸까, 저렴이 가격으로 구매하는 법
# 3                              머신러닝 배워서 AI 전문가 되자
# 4        삼성 로봇청소기 AI ㅣ 내돈내산 &quot;6개월&quot; 진짜 후기
# ..                                            ...
# 995                  샤오미 AI스피커 구글어시스턴트 디지털액자 활용후기
# 996     세무 업무 보자! 전국 최초의 세무 전용 AI 챗봇 '이지(IZY) 등장!
# 997                   AI 데이터 컴퍼니 에이모, 126억원 투자 유치
# 998                  AI 비만관리 '우주두잇' 운영 인졀미, 투자 유치
# 999     “여성이여, 메타버스를 주도하라!” 2021 제3회 W-AI[와이]...
#
#                                                   Link  \
# 0    https://blog.naver.com/todshrck?Redirect=Log&l...
# 1    https://blog.naver.com/youneeblog?Redirect=Log...
# 2    https://blog.naver.com/ocmarketing?Redirect=Lo...
# 3    https://blog.naver.com/cyxlfjq96?Redirect=Log&...
# 4    https://blog.naver.com/oio145?Redirect=Log&log...
# ...

# %%
# [과제] 뉴스, 책, 쇼핑, 영화, 지식iN중에서 2개 이상의 카테고리를 선택하여 관심 주제데이터를 1000개 까지 출력하세요.

# %% [markdown]
# #### 아래사항에 유의하여 OpenWeatherMap 날씨정보를 웹 API로 가져와서 출력하세요
# * https://openweathermap.org/api 사이트에서 Current Weather data에 대한 API doc 내용을 파악
# * 개발자 등록을 하고 API 키 발급 받음(https://home.openweathermap.org/users/sign_up)
# * New Account 등록 후 API Keys라는 탭에서 API Key 확인 가능
# * 기본적으로 유료 사이트이지만 현재 날씨, 5일까지의 날씨는 무료로 사용할 수 있음(단 1분에 60번만 호출 가능)
# * 서울, 토쿄, 뉴욕의 날씨를 가져오는 프로그램 작성(text로 가져와서 json으로 변환하여 일차 출력)
#   - cities = ["Seoul,KR", "Tokyo,JP", "New York,US"]
#   - 가져올 정보 : 도시별 날씨(description), 최저 기온(temp_min), 최고 기온(temp_max), 습도(humidity), 기압(pressure), 풍속(speed)
#   - 기온 데이터는 켈빈 온도로 되어 있으며 섭씨 온도로 변환해서 출력
# * json 포멧으로 출력 데이터를 아래와 같이 가독력 있게 출력(소수점 2번째에서 반올림 처리)
#
# + 도시 = Seoul
# | 날씨 = broken clouds
# | 최저 기온 = -1.0 2
# | 최고 기온 = 2.0 2
# | 습도 = 74
# | 기압 = 1023
# | 풍속 = 0.5

# %% [markdown]
# + 도시 = Seoul
# | 날씨 = clear sky
# | 최저 기온 = -4.0 2
# | 최고 기온 = -0.0 2
# | 습도 = 70
# | 기압 = 1024
# | 풍속 = 2.06
#
# + 도시 = Tokyo
# | 날씨 = mist
# | 최저 기온 = -0.0 2
# | 최고 기온 = 3.0 2
# | 습도 = 95
# | 기압 = 1016
# | 풍속 = 9.26
#
# + 도시 = New York
# | 날씨 = few clouds
# | 최저 기온 = -1.0 2
# | 최고 기온 = 4.0 2
# | 습도 = 86
# | 기압 = 1011
# | 풍속 = 1.54

# %%
import os
import sys
import requests
import pandas as pd
import json
import re
key = 'cce10e6093b831dcda2095dd605fca07'
cities = ['(Seoul,410)','(Tokyo,392)','(New York,NY,840)']

lon = []
lat = []

for city in cities:
    url = 'https://api.openweathermap.org/geo/1.0/direct?q='+ city + '&appid=' + key
    url_req = requests.get(url).text
    dict = json.loads(url_req)
    lon.append(dict[0]['lon'])
    lat.append(dict[0]['lat'])
city = ['Seoul','Tokyo','New york']
for lat, lon ,city in zip(lat,lon,city):
    url = 'https://api.openweathermap.org/data/2.5/weather?lat='+str(lat)+'&lon='+str(lon)+'&appid='+key
    url_req = requests.get(url).text
    dict = json.loads(url_req)
    날씨 = dict['weather'][0]['description']
    최저기온 = round((float(dict['main']['temp_min'])-273.15),2)
    최고기온 = round((float(dict['main']['temp_max'])-273.15),2)
    습도 = dict['main']['humidity']
    기압 = dict['main']['pressure']
    풍속 = dict['wind']['speed']
    print(f'''| 도시 = {city}
| 날씨 = {날씨}
| 최저 기온 = {최저기온}
| 최고 기온 = {최고기온}
| 습도 = {습도}
| 기압 = {기압}
| 풍속 = {풍속}
''')
# Out:
# | 도시 = Seoul
# | 날씨 = overcast clouds
# | 최저 기온 = -0.71
# | 최고 기온 = 2.75
# | 습도 = 67
# | 기압 = 1021
# | 풍속 = 1.22
#
# | 도시 = Tokyo
# | 날씨 = overcast clouds
# | 최저 기온 = 3.08
# | 최고 기온 = 6.12
# | 습도 = 71
# | 기압 = 1018
# | 풍속 = 7.72
#
# | 도시 = New york
# | 날씨 = overcast clouds
# | 최저 기온 = -3.61
# | 최고 기온 = -0.91
# | 습도 = 68
# | 기압 = 1017
# | 풍속 = 2.68

# %%
import os
import sys
import requests
import pandas as pd
import json
import re
key = 'cce10e6093b831dcda2095dd605fca07'
cities = ['(Seoul,410)','(Tokyo,392)','(New York,NY,840)']

lon = []
lat = []

for city in cities:
    url = 'https://api.openweathermap.org/geo/1.0/direct?q='+ city + '&appid=' + key
    url_req = requests.get(url).text
    dict = json.loads(url_req)
    lon.append(dict[0]['lon'])
    lat.append(dict[0]['lat'])
city = ['Seoul','Tokyo','New york']
for lat, lon ,city in zip(lat,lon,city):
    url = 'https://api.openweathermap.org/data/2.5/weather?lat='+str(lat)+'&lon='+str(lon)+'&appid='+key
    url_req = requests.get(url).text
    dict = json.loads(url_req)
    날씨 = dict['weather'][0]['description']
    최저기온 = round((float(dict['main']['temp_min'])-273.15),2)
    최고기온 = round((float(dict['main']['temp_max'])-273.15),2)
    습도 = dict['main']['humidity']
    기압 = dict['main']['pressure']
    풍속 = dict['wind']['speed']
    print(f'''| 도시 = {city}
| 날씨 = {날씨}
| 최저 기온 = {최저기온}
| 최고 기온 = {최고기온}
| 습도 = {습도}
| 기압 = {기압}
| 풍속 = {풍속}
''')

# %%
dict
# Out:
# {'cod': '404', 'message': 'city not found'}

# %%
# [팀과제] 유용한 open API를 탐색해서 이용 방법과 실제 사용 사례를 소개

# %%
key = 'nlGY%2BfYNAvUSfOPIoRR5qJzDO5rWzYoUAPNnC3jOuYsMWQy%2BOE30AcJLa5UJzyyD8ElHPhjiOkkDVFomSpkJkw%3D%3D'
pageNo = 1
numOfRows = 19
startCreateDt = 20200101
endCreateDt = 20220213
idx = 0
url = 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19SidoInfStateJson?serviceKey='+key\
    +'&pageNo='+str(pageNo)+\
        '&numOfRows='+str(numOfRows)+\
            '&startCreateDt='+str(startCreateDt)+\
                '&endCreateDt='+str(endCreateDt)

url_req = requests.get(url).text

# %%
import xmltodict
import json
dictionary = xmltodict.parse(url_req)
jd = json.dumps(dictionary,ensure_ascii=False) 
dict = json.loads(jd)
dict
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'createDt': '2022-02-13 08:58:01.53',
#       'deathCnt': '16',
#       'defCnt': '9222',
#       'gubun': '검역',
#       'gubunCn': '隔離區',
#       'gubunEn': 'Lazaretto',
#       'incDec': '30',
#       'isolClearCnt': '7776',
#       'localOccCnt': '0',
#       'overFlowCnt': '30',
#       'qurRate': '-',
#       'seq': '15095',
#       'stdDay': '2022년 02월 13일 00시',
#       'updateDt': 'null'},
#      {'createDt': '2022-02-13 08:58:01.53',
#       'deathCnt': '14',
#       'defCnt': '9687',
#       'gubun': '제주',
#       'gubunCn': '济州',
#       'gubunEn': 'Jeju',
#       'incDec': '554',
#       'isolClearCnt': '6624',
#       'localOccCnt': '552',
#       'overFlowCnt': '2',
#       'qurRate': '1431',
#       'seq': '15094',
#       'stdDay': '2022년 02월 13일 00시',
#       'updateDt': 'null'},
#      {'createDt': '2022-02-13 08:58:01.53',
#       'deathCnt': '126',
# ...

# %%
df = pd.DataFrame(columns = ['지역','전일대비 증감 수','확진자 수','격리 해제 수','사망자 수','10만명당 발생률','기준일시'])

# %%
items = dict['response']['body']['items']['item']
for i in range(0,len(items)):
    gubun = items[i]['gubun']
    incDec = items[i]['incDec']
    defCnt = items[i]['defCnt']
    isolClearCnt = items[i]['isolClearCnt']
    deathCnt = items[i]['deathCnt']
    qurRate = items[i]['qurRate']
    stdDay = items[i]['stdDay']
    df.loc[i] = [gubun,incDec,defCnt,isolClearCnt,deathCnt,qurRate,stdDay]

# %%
df.지역.unique()
# Out:
# array(['검역', '제주', '경남', '경북', '전남', '전북', '충남', '충북', '강원', '경기', '세종',
#        '울산', '대전', '광주', '인천', '대구', '부산', '서울', '합계'], dtype=object)

# %%
df.loc[df.지역 == '검역']
# Out:
#        지역 전일대비 증감 수 확진자 수 격리 해제 수 사망자 수 10만명당 발생률               기준일시
# 0      검역        30  9222    7776    16         -  2022년 02월 13일 00시
# 19     검역        55  9192    7776    16         -  2022년 02월 12일 00시
# 38     검역        36  9137    7723    16         -  2022년 02월 11일 00시
# 57     검역        23  9101    7677    16         -  2022년 02월 10일 00시
# 76     검역        42  9078    7665    16         -  2022년 02월 09일 00시
# ...    ..       ...   ...     ...   ...       ...                ...
# 14287  검역         0     0       0     0      0.00  2020년 01월 24일 00시
# 14306  검역         0     0       0     0      0.00  2020년 01월 23일 00시
# 14325  검역         0     0       0     0      0.00  2020년 01월 22일 00시
# 14344  검역         0     0       0     0      0.00  2020년 01월 21일 00시
# 14363  검역         0     0       0     0      0.00  2020년 01월 20일 00시
#
# [756 rows x 7 columns]

# %%
from datetime import datetime
for i in range(len(df)):
    df.loc[i]['기준일시'] = datetime.strptime(df.loc[i]['기준일시'],'%Y년 %m월 %d일 %H시')

# %%
df.set_index('기준일시',inplace=True)

# %%
import matplotlib.pyplot as plt
# df_합계.set_index('기준일시',inplace=True)
plt.figure(figsize=(20,20))
plt.plot(df_합계.index,df_합계['전일대비 증감 수'])

# %%
df['전일대비 증감 수'] = df['전일대비 증감 수'].astype(int)
df['확진자 수'] = df['확진자 수'].astype(int)
df['격리 해제 수'] = df['격리 해제 수'].astype(int)
df['사망자 수'] = df['사망자 수'].astype(int)
# df['10만명당 발생률'] = df['10만명당 발생률'].astype(int)

# %%
df_검역 = df.loc[df.지역 == '검역']
df_제주 = df.loc[df.지역 == '제주']
df_경남 = df.loc[df.지역 == '경남']
df_경북 = df.loc[df.지역 == '경북']
df_전남 = df.loc[df.지역 == '전남']
df_전북 = df.loc[df.지역 == '전북']
df_충남 = df.loc[df.지역 == '충남']
df_충북 = df.loc[df.지역 == '충북']
df_강원 = df.loc[df.지역 == '강원']
df_경기 = df.loc[df.지역 == '경기']
df_세종 = df.loc[df.지역 == '세종']
df_울산 = df.loc[df.지역 == '울산']
df_대전 = df.loc[df.지역 == '대전']
df_광주 = df.loc[df.지역 == '광주']
df_인천 = df.loc[df.지역 == '인천']
df_대구 = df.loc[df.지역 == '대구']
df_부산 = df.loc[df.지역 == '부산']
df_서울 = df.loc[df.지역 == '서울']
df_합계 = df.loc[df.지역 == '합계']
