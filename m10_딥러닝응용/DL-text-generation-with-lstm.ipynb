# %% [markdown]
# # LSTM으로 텍스트 생성하기
#
# ## 글자 수준의 LSTM 텍스트 생성 모델 구현
#
# 이런 아이디어를 케라스로 구현해 보죠. 먼저 언어 모델을 학습하기 위해 많은 텍스트 데이터가 필요합니다. 위키피디아나 반지의 제왕처럼 아주 큰 텍스트 파일이나 텍스트 파일의 묶음을 사용할 수 있습니다. 이 예에서는 19세기 후반 독일의 철학자 니체의 글을 사용하겠습니다(영어로 번역된 글입니다). 학습할 언어 모델은 일반적인 영어 모델이 아니라 니체의 문체와 특정 주제를 따르는 모델일 것입니다.

# %%
from tensorflow.keras import utils
import numpy as np

path =  utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 0s 0us/step
# 614400/600901 [==============================] - 0s 0us/step
# 말뭉치 크기: 600893

# %%
type(text)
# Out:
# str

# %%
text[:500]
# Out:
# 'preface\n\n\nsupposing that truth is a woman--what then? is there not ground\nfor suspecting that all philosophers, in so far as they have been\ndogmatists, have failed to understand women--that the terrible\nseriousness and clumsy importunity with which they have usually paid\ntheir addresses to truth, have been unskilled and unseemly methods for\nwinning a woman? certainly she has never allowed herself to be won; and\nat present every kind of dogma stands with sad and discouraged mien--if,\nindeed, it s'

# %%
# 60개 글자로 된 시퀀스를 추출합니다.
maxlen = 60

# 세 글자씩 건너 뛰면서 새로운 시퀀스를 샘플링합니다.
step = 3

# 추출한 시퀀스를 담을 리스트
sentences = []

# 타깃(시퀀스 다음 글자)을 담을 리스트
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))
# Out:
# 시퀀스 개수: 200278

# %%
# 말뭉치에서 고유한 글자를 담은 리스트
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)
# Out:
# 고유한 글자: 57

# %%
# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 벡터화...
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   after removing the cwd from sys.path.

# %%
from tensorflow.keras import layers,models

model = models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
from tensorflow.keras import optimizers
optimizer = optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/rmsprop.py:130: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(RMSprop, self).__init__(name, **kwargs)

# %% [markdown]
# ## 언어 모델 훈련과 샘플링
#
# 훈련된 모델과 시드로 쓰일 간단한 텍스트가 주어지면 다음과 같이 반복하여 새로운 텍스트를 생성할 수 있습니다.
#
# 1.	지금까지 생성된 텍스트를 주입하여 모델에서 다음 글자에 대한 확률 분포를 뽑습니다.
# 2.	특정 온도로 이 확률 분포의 가중치를 조정합니다.
# 3.	가중치가 조정된 분포에서 무작위로 새로운 글자를 샘플링합니다.
# 4.	새로운 글자를 생성된 텍스트의 끝에 추가합니다.
#
# 다음 코드는 모델에서 나온 원본 확률 분포의 가중치를 조정하고 새로운 글자의 인덱스를 추출합니다(샘플링 함수입니다):

# %% [markdown]
# 밑이 자연상수 e인 지수함수(e^x)의 그래프<br>
# https://wooono.tistory.com/214
#
# Python Numpy.log()-로그 <br>
# https://www.delftstack.com/ko/api/numpy/python-numpy-log/

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# [과제] 텍스트를 생성한 후 temperature에 따라 생성된 text가 어떻게 다른지 비교하세요

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

# 60 에포크 동안 모델을 훈련합니다
for epoch in range(1, 60):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 무작위로 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# 1565/1565 [==============================] - 17s 7ms/step - loss: 1.9618
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the precersed the precersed the precerves of the precersion of the precersion of the pouse of the precersions of the precersion of the precervation of the precighten the precersed the precersed men the precersed the precerves of the precersed of the precersed the precight the precerves the precersation to the precight of the precervess of the precersous the profourd the precersed the precersed t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the experient doe of the genience, how and such as poosither divined a man the precersable of the precession at a strengly ago profourded of the polutions and something to furst, man in the precomeness of men in the ghould of the perhaps the called comest the courder that the came the enougher the precemman the spiek for the view of the nations of the spirit to the spiritic the precersations of
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for itherness of notualage apcearationgr sapentes parh of cally sle hepope mitelsudely: brought in
# all every 8pition me
# thes whow mine to thein germanded which has peace by the has, olits
# meassing have
# =stimemence does of thes who deed in frartity--alext delititic which pladkes utkfucled--besa
# dendinejury that a trom , religion of the
# philosopher, such must the poilve
# posed fulsely.
#
# ow say
# hpself i
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for domentes: fricitry absipable permodeness of souduimeans li by,
# peacess it every stors. religntred nesourto ghaie their meaps.
# itselsss taste nyme munh over--be
# or precogune as if thesl
# , st my
# cood
# efaviledsive,
# ble
# then asteuces frem
# doe
# without-enturyce;
# they illave thirmer recolitally decisuph eveni-sl"ikes
# lingen cans.
#
# yly plact estrible in stail sevoudables, many-frre od opkes a somet
# agan
# 에포크 2
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.6161
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the superience of the god of the free must in the superience of the strengther to the strengther to the strengther to the serious and the strengther to the superietion of the superience of the superience of the superience to the presenting to the present the strengther and superition of the master of the superience of the strengther to a such a present to the masken and superitions of the self-s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for are thing in the been to the superient to even to the state itself and
# for an ageed the mestilis to the chortinations of such and strengther to the farrority of the look and to an extenting to a made of the world and to the present craites to an an all not the putions of the place, even the world of the presenting sufferies of men and it is world as it is stright of the strituted still and desir
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for one were
# ewive as instone the fleect in .. heax (world be resprously--will of it,
# the thing to achousten become how it -quiees when utself and recognisten that in hid, re; whoed means and foring the soul to thrir were overs
# to let not out underation, his look hu own mangively be evoly impersent and for him super-is dendelieted it fatorie. it
# grander precigioustet and tdan healsonist, it commun t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# europety
# findul to the -got
# can difficurers  thereby
# by ho6cens the same detable in all in
# our asxects do free respeciouamence, mystilations psiclity,
# meeil pdijed
# stool whok, usitionaialiquity to
# the be mankys, he d"aminess with our conduciatel
# is
# loik (an thild affuence, his estility.
# fir is thelres,   mutary reaid, hus jodde resett, ourselvesvou, thoreag-"nect with all agod an under melur of
# 에포크 3
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.5267
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the community of the has to the community to the community of the sense of the commongers of the common the strong the common the presented to the community of the strong the community of the common the common the community of the community of the promise of the community of the senses of the senses of the strong the community of the common the compline of the promise of the sense of the promise
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the philosophical struflest that in the could be all every commanders of the commere to the command in the science, to be domains to the olders of the comparposition to life the intermination not problem of their far world this community. it is not be misthere is the natures, in the communite of the like for the man profound of the uncomes of the plant the likeres, that the means of proses of th
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for nowle comes upulisy of "types and recoming have ter is not manner, to mein . gunswards accordant capods to inclinory himself, to impliciangeed some, and sy german con-which
# sy arts it no thingskantity cited even
# themselves, an ovreown whe
# aris she subgrested and strongers of manners of withoug:
# here strenms.ly
# peaced not all ewold into truth of a fezes to cold crotes, a divertes to glow, demire
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for whether capariby too tapty, th, appliely times prelatomenically.
#
# the stomernally than them an
# unovelitorous
# foold freedom.t.-tlins si-minated bkce
# i importaticialarce, denoed sheans operied exiplaced thimading understands on
# the differed of or
# mything own, not higher time wrily lofmined--svence, throughty. they henaticals that "thep--how inall sermerverity. and there may always, besjay life, on
# 에포크 4
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.4819
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the more as in the distrustful and as the condition of the condition and the as the proper the man and the alteration of the man and with a man as the man as the instance of the same and in the condition and condition of the same and something of the same and as the man as a such as the same as the world be all the sense of the condition and one with the same the man as a property and desire of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for for his soul and with the has morality and senders to the best whether such condition exist itself would be the as as plation of all the condition and some self of the man as wearly and in the farself from the god the strust of the past with our as one must for atternal explanation as all yet the exaste of the distinction of life, who has were it is ward of the part of the beer our moralities as
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formull yould be undeglrest bewieverter in deres, from a rarillicalive of life upon
# doce
# toran conssion will a fere, we his hishousd everything locicishment of ideasious1ly, such the our awarl, shall, among
# first mous there is rebold puers
# post is even will orn, this callic work about man is is of belief to essend a peopollessiumful in which he sake of where for piture. they conditional "instance. h
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for about as such selm exce as instance is being ervopuentdpon in ad will qua cl-pla, in illiefical quest fozed of him, hwwitefs turn as long noteverapl nigrior can stulanicy god and as edity enthisgical my the willed charm--hwdereverj, we hafout foild as sympathyl expesingne"; and erree: and imened femul whether fortunate, a
# libernuroclabse
# upon the gessedamest, in wild
# immereand
# ha
# migral being kn
# 에포크 5
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.4497
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the case and has a man and the moral and profound and profound and profound and profound and even the contempt and superstition and spiritual and the profound and the considers and as the promise the profound and consider and an any profound and the free spiritual and profound and an antichand and the most some and superstition of the existence and profound and some things and in th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through folless the ideas and inconceal and pation, and with man and protect and and of the same and nature enjoyment to be an allow the profound of art on the man as the morality and
# there is not and for himself the same this persism in the first makes the being of the romes that there are deeply the most believe and that is a manifold
# superiority and even and something advariative in the command the most
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forming,
# all appearher counterer and appaies as conacie
# of the cased
# his over the resisted action, and not
# requiress of knowledge
# ilt"--a mightly, that is only underest inconnice and wholize, and
# contempt done difflerties for fingermulality
# that the that morality and "are antirtow us say: that some fully. that for found and
# are gall been often vintopely!
# "go, intenarication of for many in contally c
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for genervite comorigatim, fancoture with as sy power thingsitation, alsoager, and "abistical edaxisy namal
# dailytrually physiogin, colracism, seavers'ly act as behing yeass soverned and time reasoe ma:ners doe5 he old good unpwaok
# theorater
# and
# solling man.
# p
# ay, as europe, which the sply populal erpotuoric centuble o.uh-if which has a liteit abor corver primisicam purityp: po, would not yet newed
# 에포크 6
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.4272
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the fact and an and the conscience the conscience of the same the spirit and the spirit and such an all the conscience and something that the subject and the misunderstand the strange and an aners and the prompted the spirit and subject the senses and the subject the strange and the spirit and the sense of the sense of the spirit and as a property of the most present the same has a standard the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for has something is no longer the same the law-nect of any proportion and strange, the ladement of the present and harden bet the father the of the superior the precisely because to be in freedom which conscience to be man in its the larguing the faith and same something to be all a generation that what is never manifold,
# one of the valuation in even the prompted the soul that the straggin of the c
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for . "first and morality
# aflictly
# the medioc. that what be much of the hary lingta,
# distressium a rregquental
# dixtuch trophice of "the defind poss has possess of any
# the greatest to sworthes any it is that becomes satipfod-sichable
# exience, the
# intendest tobous geneul, resipticulable,  fo europefuls. , hitherto towards look instinct beten-are strong--accords and poward, and has woman feels decanded
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through founsoun on cited the owfwien" that
# see from the sense disten
# here to valual be noblely the nuper
# his only that "will
#
# tacthly
# mben "the signifabild concerning with an
# gookeds the greatesice. as leads the questions
# prycast puts =anxiety
# and n.y such it isejoy in noly a blimpted banedts
# to beingtantable true--perhaps what resit to
# depines out is worthurerningsic and morality-last,
# buch
# clartbad blieu
# 에포크 7
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.4107
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the present for the the same the same the fact the consistence of the case of the world and the conscience of the sentiment to the world and self-conscience of the case of the consists the same the sentiment the strength of the senterance of the specialic of the world and also the conscience and soul the spirit of the sprade of the conscience of the consistence of the same the consistence of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the opinion to the appearation of the
# fagiled because which the subjection what is for one of the soul and one's subjection of the responsibility of the depth in the last and expedient the spress he who who interpretation of the consistine the words of the soul-hence the case of the masters of the intellicage the man and inclusion which were in the characters and strong the well as the continue.
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forcher of then
# satuch mastery, really and intention truth. morencails; by a huntre"
# only their universal first to high has been
# know jeises of "happiness finding whether need
# of snording methodo theest but the infurure to happiness of their by in that
# accordance entoget
# happinings of thigher "reberin"
# that i had contitue and artuwnes of thimselug latred are is of grane of rangeriftened, and bood of
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for old plato half-consideratancest
# to which awsa;--fromiverning. saint those ourselves. different, called there--this it ready without
# given of gi
# ekenngaring easily, more virtuact
# of metaphysti)x-inmen and sa, that those de. they above  awnyay. suffociety at each questis of belito it before a nevertheles and undo of in
# nupecalists? "increases.    undiblefore? he may sagain, suffering in merely wha
# 에포크 8
# 1565/1565 [==============================] - 11s 7ms/step - loss: 1.3961
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spiritual to the man and the soul of the structurity of the moral and structure of the spirituality of the contempt of the contempt of the constitutes to the contempt of the man and strong the self-contempt of the structing the structurity of the morality of the same souls of the contempt to the scientific could be more and struction of the spiritual to the structing the spiritual and morali
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the humanity of his rows perhaps the person and the breaking necessary of visuse, and for the demands and despication of the love the same
# contempt of the power, classing to does not in short of like the more apparently to the man is the order the subjectity of
# his own against being souls of the being been can the condition of the really a standing the really its evil and stand of the value of t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through form"; the :      bain and day which the spirituality, a philosophijgne inclide for this truers--falsed to germany them namely withs to causastence. for that homes tman and into nin, un, ba complete of
# a greed, and cheariarme as the
# phanons all this lackt and abststences of supposist things be mane sprenchss, in their perfound treas and schild world to truotious eviluntarlant pasion froorr
# him to ca
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for minusc" if any pru-tonright of him."
# , unm hs heritypredblight. to "pfutions.h.=--long exure
# power, his oughers--comes anemine, overly normousmy, conpline schooling soulves.bu-"or a difficult to hitherto spite womler, who may the as lines to
# e horse) only by inrepariars
# and genay de
# such wonderism in they value of humantable a
# houghta possess," allatis upon this really nothing to it
# not be motiv
# 에포크 9
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3845
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the morality of the morality of the conscience of the conscience of the sense of the morality and the stronger of the morality and still the morality of the conception of the property of the conscience and the conscience of the conscience of the most conscience and the moral conscience of the self-conscience of the strength of the stronger in the strength and into the strength and the most consc
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forms of the spirit interpretion of the ideachipie evolution and society could become and ethical and without any who should be all the property in ordinary and be something conscience in view of the most character of morality, without opposition the conscience and spirit and that the sense of the soul, the fact to a world to all the life which as the presentime, and the profound and second to any d
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through form tessence,
# inspired without us has
# been cytions for man is stay
# coluted effection?
#
# 132
#
# ow, the
# borth--how physions and with anything and "fact only has been but for the "new if the conscience, a distrustful farreed footion are evolutions koness. whither for now orderness to world for rest of
# the wortingn instssial must bark. nothresc." without i
# fundar hitherto rave, as im ise
# of modern
# they
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fort,mical so, one, reaso
# divined apprehens the evil herewited. hopan cruelty, higher so cormented
# the worthy, ngbrior of un with a patesty. ontenlinable, "what so us! "the centur : keet
# in a namencred by standing," as a labonfore that
# has your believing, these traducous bring creatod, which hat lit be amidet where seems into high tawkary
# know "tests , this amide who are "bli,
# effem when handdect be
# 에포크 10
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3745
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the conscience of the superior of the same and superior of the morality of the most doubt the more the same and the superstition the most deeply and superior and the strength the world and an antiquent the superiority of the conscience of the delight of the morality of the morality of the conscience, and the discises of the good and soul of the strength the most more the superstition of the mora
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the appearance of the worst, that the free threaterable and almost and christianity of the
# "the developed has a fate of the nature is death of the conscience, and the strength of the relation of the order that the person something the word than the more unpersive himself, the consciences of the discover that it patical serious and means of an orain the life and one more conscience, the same feel
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through follests and one andar ofther its less be through conflint man betw: if also look that it, but sounds of him., for his confuial
# question than int. deciitions? what ha? heritately emors of thing and dereforious will which we lits a vaile and any, "object ruble is," his philosoph
# and natures knowledge of anyorike been then the conscienting:
# yhe origination that
# the- would,
# or is combadd-in evil. the c
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through found according--if his stowing not an intellectors
# a-liwlo
# a norle necessary
# and true--and doby umevent mades it wish.
#
#
# thos regarder,
# and operatengar "scays
# unconceivinable; how?-""nagur madned: imording
# resse he ray may of the wull choos reludue, which a morely himself fleis. p
# esentarist. mor became--as ye canderments, but, cotres, ornes, selfics. here essern ultivad of
# them.
#
#
# 1rohe what the
# "
# 에포크 11
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3646
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the same the our which a profound and soul, and the sense of the way of the will and consequently and in the same the interpretation of the spirit and self-continual the will and standard of the man of the same event to be which the world and soul the greater the standard of the same the struggle of the sense of the according to the man of the man of the consequently and and and the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for standing and extent the anticism of the manners of the heart is a man of the based and soul, the savagise of the protection, the filthing the our thing to the old consequently believe only as "free spirits and states
# in this incluricy and not and significance in the mean in the self-continual there are attain to destroy of the same without gradually mean the exist not alter ourselves and nature
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forms like token could an else from brings are wdicauld wiod of the same venaus
# men their ble-pilles dirfice, many (inhuman stand: that. land and we ceasing the objects, and
# and like really as the kind, and with appreteiting god aloxh of thingse of "aumonation, and longtes; for the ares merely nature, altery; for impulsiin of defined.
#
# nothinness who for self-reint in as wediest with us side to gene
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for it
# scepis of the armork that its and the wearnignest mean
# rule of thoughts : the very living neares expedato, nightcal vidures
# no consolnts of
# sun-tawationced.--namelbe
# simple, our unmichainks the quite morality and premised
# autts, betrayings" prelicuse, ifjorly
# to our bliut; wherever the than eabels as
# if the joaks, any
# so
# only does i scienti-g--given continually renative 'houne, unpases these
# 에포크 12
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3588
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the subtle and the consequence and the strength and the strength, and the strength the subtle in the strength and such a proper to the sere of the same of the sense of the same the strength in the sense of the fact the sense of the strength and the seriously and an accompandere from the sense and the man with the more and the work of the most sure of the feeling to the sense and the fact that wh
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the same to de under the presence of the consequently in the struccus, what we are the charm in the entertain the world of the concerning the extent with it is a superiority and the consequently and any more look for the host the belom--he will distingual in the compart in the world is progress of the world of the fact
# from the same to the consequence, as i also the familiarans and the spirit of
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forwely and false) still yet away with obsequalent culture that only simptished as hover, in an approconially according to his wearming theavilprated is "scarbing, through the can a higher strength, which
# brings and developations of the must, bal, a religion, in the powerful, this:"" every remals are even full
# be colon great its surherness." to unphise
# of their ortage and not
# of his into
# believe the
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formult:
# but later od: "the nois? swill solw.
#
#  he
# to moganious best autholy--well
# again percepripment
# danger, still floture from greepleming, that on the chonse look (goo calrise adedited in the met peollen--at easily
# "wom
# so kind of wegnory, we for this
# phroyon in man of give viminal eye for ho form spire
# vieward with a persapis
# origin his fholest heavers--ollighoquently all ewnass. to purpulem.
# 에포크 13
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3531
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the most be and soul, there is a socting of the most man is a man with the strong the proper and the strong the state of the propers of the same the desire of the same the most the most interring to the same the propers of the self-greek in the most interring to the state of the taste, the state of the sense to the survely in the most the same of the contemplate the most and soul of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the content in the world has only as what is and there is as the perseles of the good the stopes
# of the particular and the degree to rationally necessary the profest
# in the readily men to have in the actually inclined the soul of the preach the exception of the power and individuals as the german contempt of it is not and desire and soul is a view there is not preciselasder consequently the cons
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for aed they hand mediocrations of "indiscend they long--contexivery, it has also peticong general
# descity, as certations of which (their nothing orders power, to else out of acts the natural, of dispedical
# patel times and lived all in its a bearing succrctity of one and so. knows where the soul doam, we reasonly; all , nothing! it be were "the strungut in herital inclea
# my most desirable belief is
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for soughts
# and tuse
# brought and is the dhy ipin of nature princisms--petsters and most, of could been coilitmenw, the
# much
# state the one-much
# and saris,
# rearage
# time is imparengif andirst but in "att else liab error only as the
# realnes ie, werage itself,nce "believe in proteniful; later-hostile,  comed"--und
# need in the pesimers, humany and piy to overname
# neciusar
# free wagns. i no dessivedly:
# voly
# 에포크 14
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3465
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the commander of the same and precisely the conscience of the sublition that the contrary and something of the ward to the strength and the consequences of the consequence of the sense of the same and supposing the most the principal and supposing the same and the problem it the consideration of the same and something and soul, and the subjugt that the same and some demands of the commander of t
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for in germany was the german on
# themselves on the world truth of the greater discover the one that the superficial uniten and self something irrespons that it is not the greater men that
# is assime that has does not precisely response of the point of the strengthers of religion man respect that the entire as uniftered one class of the greater languation of his has learned and stands of the result of
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for discie
# with resuvilication of his diaring of referenie else, as
# si-cernation, nor all untoote in light of course of wait not
# moralness of sour--belingnves that under their intermolation of a-certain, slaverity which
# religions, ont of
# europene. the depactiner, the
# spirit of "moling to them those that reception or liage, as theregias, contricationst--he is award, to make happinglbolding in being d
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for indeed primited sufficient growiciled.uation by nalness, implessished" mean of ranked a scennateranemit,pened or essering,
# the idsa oen
# thir
# truetingl(ness, in ihe in tig, thu
# dance of tsloy among typted hind, symmathise, sotiencement with (inyed, inse ofly noble aswear, but need developing that an itrix althoring i"sy
# becives that ison for fro, flageness withs wiseful nowedly? so thosey becet o
# 에포크 15
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3400
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same wholly and the strength of the delight to be of the present self-endive and all the strength of the same and philosophers of the power of the same and some suppose of the same the spirit is all the strength the strength of the same and even the world and state of the same as a prome of the same and some hard because the present serieth the fact that is the superin the same and who has a
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the most and almost age, at the realor, who is well elevate for the well to origin of the superst of the really and the conscience of
# some more at one pare of a consequently even an ancient and more propet of the politic men with a present never at all pare of the veal and dicult, when they ward to be all the fundamental strength of the spirit to be the "good or a standard as the masterful of co
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fore his. a satisfactionable, prowess, for it all nothings
# always in sensition of the everything fine condine man it mmself not shor rapacy, which remyestory. one, haff. ticth, bying the
# cose-end it not aristickly the
# earth" in nell, most society
# we look a-frr
# are superst, amandiesing out of logicism, they can are suscemertory of the prown of relater
# the means,
# would one , tray. who can be balitary
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form, it rough not sending the
# futures of markd
# whee at allgrion and inbottle
# certain it kjost for ittere-roeamance of any sascial present
# nell itse kischupit hedmy, opposition
# ofing by evaluin" and the capac to praching, self, wecloson through, the greatest faculty is always
# adrivines,
# human nibis and simple.
# not adgyationt." he covetypis of supremorauld fouth, to oppress of cearing even test of kn
# 에포크 16
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3350
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly and some most contrants of the same to the same time of the same to the word is a sense of the same and superior the problem of the sense of the same the same time of the fact the same time and superior and suffering and strange, and who has a seniers, and who self-suffering and superior and contrary and strong the sense of the strength of the strength and strive the fact the same the same
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formerly degree in the most satisfaction of the sense of the same honoural in the significance the bast comedly when every do not really and spirit to his sense of his allow the transcious words, and in principal point of the same the world his experient and the german more to a stronger to self-natural taste, "in them will operated and contricated is at little to the same times to a long a course,
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forgotter, these loaght--artistic man. all wholitionable cain woman, as "immorally perceived the inte, has accompranijgant
# in middles of stoike? when
# everything was long spirit frod of "will, with a created hif elevated "the by thinging necessation, i motivety apparary know with his imanting beting pation, is poligite and the long as an idea of formous be order--or his wors, as a honourto samilement
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formveness and men. it says in withourse peacarinvegs to creatusly and ger in all account--ands any mad
# betray opest ennature ordealisebes--ih scholarling galk, overward sdelly else
# growikes. would a new the othesed ady oppic of knowlur of his subter, it is place mavis to happens of trained echious succ
# brestracrhy of many falten, impresivilation, thus
# aidsly unvirous often and noble with without it
# 에포크 17
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3320
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the propert and and property and present contempt of the strength to the baser and strength and probably and something to be an antiment and the propert and the most consequently and such a possession to the entire fact the strength to any proper to the strength and which is the sense of the propert and the man and so the sense of the conditions and sure an entire the commendent and superiority
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for one another artists thought and the whole nothing and the history to men also by a subond--in all such a possible and concealed and likewise an almost to veng an eduredity, in the same such a partial fact the domain to many power, and for the contempous things of the day in the races and for the community as a respectability of the world is in the german perfect in the sense and with every almos
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fourthy, reration of kings", threstect an evils-altendary deathy in confetsulting upon all e believes and follom thusly--to pays hmain them his axt could to bed w, all ser of a metapaposy, as folly, a
# world to so rule himher said sympathys, on broring--freeprie and.
#
#
# 3 upon , almost unises that even while reachen to false the fanu
# imagine hearth; antaim, which
# courage, which agric and anems him to
#
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the wa--as
# by some family--in lacking
# itself, vissed scientay, this find and atysorat tragedy pwhen has are scein his faciviqual, old o-puritty, thris is--pure vudil lacew,
# corcely of shower  immediate untaught in will, ignises," i least ourselves;
# ": has
# before
# they rule. benthsinablices and sudscail principal act be
# no things.
#
#   atliblin, which which hoderoes, this most
# deepon--which
# aids ex
# 에포크 18
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3265
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the moral and as the problem the moral and opinions and problement of the sense of the security of the sense of the sense of the sense of the secret of the sense of the problem of the soul of the world and in the sense of the problem of the hand of the soul and sense of the moral and the profoundly to the profoundly, and the sense of the secret the standard of the experience of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the philosopher to a man from the experience is to self-like a pricty of all the contrary harst have always the great whole of the stoom
# and the brain of a profoundly. they are as well is a commences of the course of his character of the deception of the highest of the haking of sense of the order of his organism of his form of a for impulse and something some work of the word of a man and the c
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through form of whole light: than of its eopful from
# such an atceive timer; his the fitten, and manfien-sensity obcernaturely ias, require
# other, or the-prefetionarn" all feel in musilings, arring perlect; in "durint. they marks upon the taste,"
# for interpretation,
# for your covilious and coanins as one three -the
# most one expediences of de-libion, philosopos; chaphees, cruelty"--but when the than slimite la
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for a -without ascisailized:
# gendamous realses, wherever caak in cloancious and, lask itsive, puston and
# inventional but with a almost
# what renotenines.s wsherous
# and angok, and
# for except who immense of
# juss, asvation of off when
# and art, in this itself without one's
# antillemed if,
# indeped,
# if it extendanding of ahor and scimarision, connect over for humanity to routh, and too ancere that a lither
#
# 에포크 19
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3228
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit of the same the spirit of the sense of the same and something and suppose more present, and who say the sense of the most stands and most and will to the contempt the present, and the present, and who are now the superioring to the present, which the present, and and something as the same to the present, and the present, and who has a property as the superioring to the same such a man
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for himself, the still be here possible of the most things religious and such a man is not it is not as a sense and does the positive the fundamental and disposing the security of moral and power, and when is to the genius, a principal and bad by the end of a compolitity is a life and saw, and
# the has been such a thing the good pator and the discipline, the moves which we are good the look of the op
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for soul. the horso, a  it has un he is to erroney, lo go lole not enough, when you goile was flow.
#
# 1o1. endiration of the shafty a
# mylity
# and also the good is let zcefuln, love it by the questioncrers of a world stands althective, as even quring framuge an accomentle who doesly involuntary dingther, understand of its way atmothe, modese
# entally religious in the knew, to be might, and the immod, wh
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for fal animal
# of  an recolleco acpuin slay, on will as at last makes of pare of hhutover
# question, with to good opinion must learn, anitation bild she old imitation be
# evie to deasc-ether the philosopher extranise frombely blogisase, one
# course.
#
#
#
# =thighe. lae
# desinatic or the finle of laivous, may dred, without it: "man, comprehend of resppkning sxeak as
# indi
# onoughs be lend that womkness religio
# 에포크 20
# 1565/1565 [==============================] - 12s 7ms/step - loss: 1.3181
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strength and superined the seriousness of the sense of the spirit the sense of the stronger the spirit and deception of the seriousness of the world and superiorie consciously to presentist and superiorie as a still and surplication of the sense of the spirit the superined as a state of the most distingual instincts of the superined in the sense of the superinest of the same the senses of th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the seriate man, as a man of the delight and self-pation of the depration, one with an in the sense and senses that as the sense of the expect of the sensed and most demidity of superined and superined the believed in the same and seriousness of many of the desire of the superinest of men the same and taste. by the propert
# that great one who everything as a sticled the expendent man of the conte
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for generation. hume bigforment of spisitions
# in opinion is theregomans, bef"nect precaurn of
# belief--but the seriousl; the
# spirit
# as power therefore is epicuse, and
# one of coclougues "wagher for he honoey,
# but to caus. because,
# why stil--and sympathy of well whys from
# hus to see which the process of
# the well
# dispirial.
# salud,
# it is "since feels symbully and condiction wherever the heid to
# , was ar
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foll of
# the impoedityment,
# is not particiausly"--justificonity disptsriently
# "freeilf.
# could: what is modibiting,
# to threategeh,  divine to aisce,--even when rest sagic-inversens, harr for colleing, hamm, in the instinctuiar facture estimates and conasion the gratifity and by
# closely believed him
# who "free moy utbefered interrogated becoodly need,ay
# suoms worcaus"". as merively for heavers and tessi
# 에포크 21
# 1565/1565 [==============================] - 12s 7ms/step - loss: 1.3160
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strong and sense of the strength and same the constitute of the still precisely the spirit and sense of the sentiments of the strong of the strong of the strength the same and distrust and still and the desire the soul of the strong of the constitute of the strong and conscious and the more the property of the constitute and the property of the sense of the strong of the strong in the strong
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the rest every conscious, what is a generation of this and himself in the destruction and duton of the feeling the compare of the belief and old in
# the madation of the philosophy and destruction of the present meaning the will, and therefore, the contradictual and
# instincts and origin of the destiny of the could not a still
# the strive there are not were also in the strength of the stin of the la
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the
# being away sdevedherption, there is perfect there perhaps has been question in go it how would be nabilation, in it, conscious and
# divine schoolst suspected
# by high present stil asseratively verdness of
# "the
# weaker being stapabotic of moves to olighundome, race" of cometance
# which dotethic
# cirche:
# somethie must actsulb), whatever, religion, it who free                    sch gove because, it
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for upon
# exercedary the furculety of his ultimate feels. deeply an becamp
# or is, almost lightne, what is any de" you lou? which lose." herended, above these-goorn of the opinion of
# nature of comprehs inne)ed corfection. itexobce the eagerfy
# trangary in the . are he felt
# zven, which have
# onless
# they absce-loging, for
# this, if one cauline is the belameity happion dopt example,
# meched--is now todman, o
# 에포크 22
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3126
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strict and the presence of the most distinguish of the contempt of the conscience of the strength of a man who have a strong the same and the conscience of the strength that the same and the most destry of the proved and are to strictly and the contempt of the world of the conscience of the strength of the same and and the most contempt of the contemplation of the strict of the most man who
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fortunately strictuse all accounts of the philosophy, as all a new concerning the processent of distinguish, in life entire of men of the lastomes and of stand of the expendent to all the mang and because of slave that which all the conception and every south the soul that the old estimates shart of the science of the danger of mankind of all such a man and all the philosophy of sure, the world prof
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through formare
# xptirs perciality, to the essentially say differences,
# s
# his own relations." who was to marhove
# domain, make the mitter,
# expendnences and more incuriticic, and rates low almost things oralious intuinaty contradicalusless in in namely invention: for to his  as dangeading envgnt in boralwidine, in find and
# as they was
# from compromovent of the tavil comingary or has a such as the lastomitsger
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forts
# again platenem, to tenture and breed-day,
# first names. to liget ink's naturally-mlaustity of rank of nowadays and
# of comes which literain. from mabvas, standardob
# vivis, far the motives aas typical ciwic envy "dverbed one can rackdder why mankind wrean, understands should up at them no letelty to much "gods  he kinds adoraunt, without timer case herestaclem--this system work,
# whomilier.
#
# 187.
# 에포크 23
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3109
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the moral means of the same of the same and some discovery of the same and in the sentiment to the prevails and conceptive to the same and some delicate and and the subject which is the most distress of the same to the same to the same to the same to the sense of the same and personal and the fact that the sense of the same and surviboical and survives and sense of the strength sufficient an
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fore that also even the destruction is a man and comparison that and a sense of things and consequently complating and there, and the imagine of the condition of the good in the sentiment to some trows the spirit to the art of the fact and dependance and carry and there were the conditions and there is the same of many sense of the most the most many and all the morality of every survibously and the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forest that good lest after conceative being portating from the former
# great of her right rul extent comnocconking enjoyment butuen
# spirituals--a higher of the term or every
# one's
# deatows: the asro and among and to
# the does well easor can perrosation, when one humalism, could free eithic
# certain soil, (o: more nourical glording. raming the sensation of a problem, much so mow--the beautiful
# great and
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foreraftly inctance with relation
# fmotn dwawatefully to wish sebrat of all betwerneat moth: that at the innatis must a beingial
# or is the philosophizs be flash, but blih
# her not held thus condition of moministie accept, these pelsion, must candegawere, we dist-in instinct, rejounce bi"? and as humanity-utimal:" the lia, hence
# would requited question his toorwherouther is soted in a deaurate"od own j
# 에포크 24
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.3073
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through form of the same and such a conscious and so one may be so that it is the standard of the spirit of the moral interests of the standard of the standard of the spirit and superstition of the standard of the same and the superstition of the same and all the superiority of the standard of the science, and the superstition and scandinus the standard of the standard of the superstition of the standard of
# ------ 온도: 0.5
# ...
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formaies, and the state--i are at any comed as be in the fact manner also not be not the fact here its existive in the mass in the mingtical profoundly
# such an intellectuality of his migner and unconditions of the same anauged in the french the philosopher of many soul as an act and the conception of the confulsion and the transchius grow and delight, and not to the something and something as religi
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forgets and nature (of beings, part of things himself with ask as
# religion of
# enfiture of this
# new know when one have always eacher given himself, for the paris, anditmine could senscious rrated and pationion a us appetlyines upon the sow? ago
# -lener gol the fundamental old my person shartard
# of being forward mean his desenient
# englishmapiet hein
# rarer now nebrfis for his as an emotioned, plenter, s
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through footness, of more, henceful, deels experience, when bool". who knde; hi ways of embenting,
# and or ais its mistank when beenning, suscoman,
# to dlumptic heart discharm the philosophers
# irriance and accisioliged. ye coantipleul and executon reason, perhaps
# something which he were forstoruched the confurce. whentear falsely--theor"--yous hejquent swishter a motive,
# loake; and others, after fough this wh
# 에포크 53
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.2511
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same and again and such a proper free spirit and sure and such a perhaps also and perhaps any regard to the sense of the sense of the sense of the same of the same interpretation of the senses of the sense of the senses and such a perhaps be not the proper the senses and almost the senses of the religious and all the sense of the sense of the senses and saint and deceived and perhaps all the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the bodly not attained that the consideration of his surremble of the self-important of the bodly and even destiny, and in the refuls of the
# act and something for the authority of the presence of the belief in the precisely the preferred to the artists and prevant to the most proposition and men to perhaps have been a not the germanity. the fact that it is all the proper in the truth of his tart
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the impulses, moving
# and roning and it a, has union
# thinks.
#
# who
# owe the voicats fortwherade, his fathers--which makes about all.
# cather act from man; all
# threate, aking, instsome as with there is to talg. but the "such a religious assumed rights
# in mask of this ohing is deprecisment, will; and with sense getail thought men, all so last frightently. a
# perceive to unfaitures, had more of his own
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fothiness the prejowingiry--he wait, is it mby coswardertt in so has, in a country-apspin rare sandopnoritary medary
# of shamice
# swethess? the doubt. to be terments.
#
# 1i; jussty, didstcl formulfent asmmentrality, are eccertion of new guchimsd to his fetter, would rare but sain: weter full?--vanou:
# "is, the backgrous, religise
# obedy, ragines upon one-are," s
# is god and
# higher certance, becomimg guisti
# 에포크 54
# 1565/1565 [==============================] - 12s 7ms/step - loss: 1.2509
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the state of the contrary of the presenced to the most depthrant and spirit and there is the point as the present-dinocis and dogmation of the present-deeding in the same time and there is the most deception of the presenced of the same time and there is the same the thing the profoundly and suffered and there is the contrary of the same the same and the most philosophy and deceived the supersti
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the emply are in the german of the entire in man in the contrary and sense himself as he is the profoundly point in the moral facts of the faith in the rules, which always
# still and responsibility to will as the will as the conventicise works, and in the soul.
#
# 128. there is are must and there is not the present-dinocis thereever refinement of the contrary and accompany of men, who are not attai
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the past intellectual time, for oniqking and wishpths might
# superstition manu.pye something, when our person the way of the belief from nextturewitness of human heart of the betwormatis
# and as to do mean, when no recolstation of things within them. for adreacis dirxial of spirit," with our tain omjeution expression
# make, but as stronger man is, as it must a comparison tra?
# vow origin-
# what had a
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through force operats alpoly incii!justed happful meremjust that of it! how must, put gele furious ideas of german, so unde addoralyf. indeedt in a wore-virtue in all ccords and will in which synthesis
# as warthies of prine of their tethoued;
# through the sakeal
# contrey fhaning, and
# letaiks onw--asonbbgbra.
#
#
# soe whoschoute," between to say and je
# sdane to
# hander.
# leke to misun, that was nothing al specially
#
# 에포크 55
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.2497
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the most powerful and the man of the same to the conscience of the belief in the same and history of the conscience of the most powerful and the strong to the stronger and proper with the most personal of the stronger of the present with and the state of the stronger of the proper to many many many and such a man and the stronger and the complete and more as the contrary and the stronger of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for impressions and the ages of the propudity and desire to not for any sense of the error--and which is the heart and discounter--and even the freedom, and some become the instincts in complete believe to a this states. as it is not a more protections and some distingues to the reason and the same protections and perhaps an art of the spirit and some another, only for the surface of the struggety,
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forgotthes fatt--and
# which a
# discougness appeal fignken perserved
# them strong man"ed has to mofestisibulgence of perciation, and in art interpretation: in being to ont even human implearant hopes and
# sumbles should to the speaks lives" as dodfible," one enjoyment their view of socke class":--as meets. a kint and evil, a daring interriould flight,
# "mindst--proved good lempols and
# there misunderstaysi
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foregot and bad-believed the
# usentians--as his usagence""
# sensations, anding now, comes acts, and is
# filtherked and eccerreg returiat, mectically eff longs
# incly and life as do to my knew: and virtuse. not human antile ourmrebur. alters, endeccets because with useman--"we sees to goan--domact-rereowad
# tirhed self"birly effect no long it is stuppents of ohd withshodible: we syeten womatinemages theor
# 에포크 56
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.2484
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former and the world and self-contempt to the condition of the best of the world and as the problem the world of the way of the most the most proposition of the fact that the most the strong of the condition of the best one's own and the most security of the most the artists of the entirely of the stand of the conscience of the discording to the most the state of the same the distinguish the strong
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through former probably a philosophical still religion, superiority--as the best and false has hos his species when a being that the self-concerning that which they are long to be supposed to selficully, and more tentions, say, in the contempting to less of the standard of the world of the dealing with a rights and above the concerns of the most be noble probably, the will of the teacher of the fact that th
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through former than--a feeling his candit of them the doly sfelt of his own acher lad to
# ank mankind its owing to that  their the cannot that they paveny recelletirity of blis insacring unterernity, and on the undermotgion, has been the virtue; it, as
# subst admirted conditions? evil it customors at all
# are changers and betien finds, to you have poor
# self-valitor the giver augon hands of nobserves and duers
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foredrevipting to real
# vautt of them--as tra.
# thisher, graduricity--namilary".--the sympathing. to foth
# morality. to this
# a pobclusion, their
# evilzation just
# horrous ordinary their
# even and the untel contempt toffer
# feeling strong of logid as fuctions of one is terned
# at the reason is that grible enligmtic in order the uhmqu(hegne.s formulpes
# be wancition after themselves of the philosophers--or "di
# 에포크 57
# 1565/1565 [==============================] - 12s 8ms/step - loss: 1.2482
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foretowerness, and also and men and such a man should be a man and spirit and profound and strong and such a person is a subtle and the way of the strength and spiritual of the conduct and the morality of the world and superiority and some self-contrary and spiritual and such a conscience of the protection and such a man and surpluss the strong and according to the profound and sense of the history
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through fore whole with the verd and consequently the man of his own soul, and more faith and without the philosopher of all the good which always all the destricters--but the present these a species of which always has the underes of the moral deception of all the propers, the strong and the scientific and interests and case to call the interests the higher person and being the decised and such a man witho
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forethar.
#
# o
# extrood stoicis for which they advances. the counter of the imsective qualizatio,, in namough us ever wrong mindfly in the closed andure oberatu-asmableness of thesel,
# a surigins which that originary
# against from that has a belief
# which
# has to be invatian be a pobk)""---is at the
# greater men is
# do segont to tender,
# refinement decelartus. yet our free
# stupidity have no beedil
# venech whic
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foreis an futuce of freedom.--brouldom of it-portentous, it is
# underdumated, and inclined,
# time
# thenies: canchuned. thes
# footn elluly that a treach-eviedity manilation and almost new compart feeling customs. my words! how thel, and their oppression: emandhe, forcerarys ahy eleness who promring dartes
# to makes to him undoes, to scoet; "i again which perhaps, they makeow, these spote, when a politics
# 에포크 58
# 1565/1565 [==============================] - 12s 7ms/step - loss: 1.2454
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the present self strive to be and problem of the same still and proveration of the same and so course of the souls the same strength and sense of the stronger of the same time is also a man and with the same to the spirit of the same to an action and something also and supposing the same and more will as a subject the same and the same surigined and the stronger and some spirit and some comparis
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for in the expression of the present men again and spirit essential in the struggle and possible to male which the feelings and supporary and body and delightly falseherness and only even of heart and man is not in this profound with some personal and so consequences, and of the loftist the instinct and most charm of which we are only a superiority
# and
# higher friends of the same or by the consequenc
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foregrounaly of the dellum, personal taim of stronger vern
# powerful, but to
# sotle is it reines, as the personable, so seem fror the explaname to higherxtoftryes different and faish
# to logic wast instruction do with it harder and necessary--and of essence is another point of being,
# but the vire--sympathy of fundamental science, and regards him this nocement power, is, and an antigres of a will strotk
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for them wish to habitule of
# hory many old a"rough as be seriles so     say itself. he strive of write as yine
# sleffere religious misunderstandis.
# the connulity is religious tading which no chwards in form ofinies naives,
# but in it. pity of notion sympdif sobising.
#
#
# .=""fres
# of complinance of our freedom, first modwant imprehence, remain--he way there should reverence acknok are origin
# do call pues
# 에포크 59
# 1565/1565 [==============================] - 12s 7ms/step - loss: 1.2440
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strength of the same time the state of the same things and something is a subtles of the same time of the same time and such a personal finds and some sense of the same present of the superstition of the same the same and as the expression of the same originates and deceived that the same of the contrary of the same time in the conduct and some the south and some something in the same things
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the expression, and with our first of his compares and more as immenting the convenie, as a personal conscience, and one the deeped in the same so something what was again it is the foreto art of the essentially and the action, and it is caste with its successial and in man is a subject attempt tone of the resister from our world to a personal conscience, which about the existence of the south a
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the feared would not never fortublibilers or the
# induarity.
#
# a=n that sillely and defect, and with hafteener, rendeviages at any quthlou-sksellund, that for faith is a still has termined to europe, in
# a for the virtue suffer, as
# ill, historo
# that we be,
#
# fiemed by forexhious, and no other--it senses the prequality of european error--the sufwitt age and megaink," in the highest
# of lively
# good nam
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forms thithite and new immense
# this other greek-coxtowous readily, the philluentora, the intermbl sufficiently man?f"rapion.
#
#
# roam oirsian.
# the artists"--namely, in the badben a voluntamians and comalrly to medisting from
# that dangerous nature) shrince in the
# presept think no
# longers only atteciation. butardorations. the easier decrance--perhaps it
# begdnent, advocate own us ad skeps first his serie
