# %%
# 내가 만든거
# 재고관리 프로그램
ojall = {'과자' : 20 , '커피' : 30 , '아이스크림' : 23}
ojprice = {'과자' : 2000, '커피' : 1500, '아이스크림': 1000}
while 1:
    ojkey = list(ojall)
    print('='*80)
    print('''
                             재고관리 프로그램
    ''')
    print('''                            항목                갯수           가격\n''')
    for i in range(len(ojkey)):
        print(f'''                          {ojkey[i]}        :      {ojall[ojkey[i]]}개       :   1개 {ojprice[ojkey[i]]}원''')
    print('\n')
    print('='*80)
    what = input("""무엇을 하시겠습니까?  
    
1 : 재고 추가  | 2 : 재고 제거  |  3 : 항목 추가  |  4 : 항목 제거  |  5 : 재고 검색  |  6 ; 재고 현황  |   0 : 프로그램 종료     \n """  )
    if what == '1':
        name = input("재고를 추가할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            mount = input("얼마나 추가 하시겠습니까   :   ")
            b = input(f'{name} 항목에 {mount}개 추가가 맞습니까? y 이외에는 취소됩니다.: ')
            if b == 'y':
                ojall[name] += int(mount)
                print(f'{mount}개 추가되었습니다.\n')
            else:
                print('이전 화면으로 돌아갑니다.\n')
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
            
    elif what == '2':
        name = input("재고를 제거할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            mount = input("얼마나 제거 하시겠습니까   :   ")
            b = input(f'{name} 항목에 {mount}개 제거가 맞습니까? y 이외에는 취소됩니다.: ')
            if b == 'y':
                ojall[name] -= int(mount)
                print(f'{mount}개 제거되었습니다.\n')
            else:
                print('이전 화면으로 돌아갑니다.\n')
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
            
    elif what == '3':
        name = input("추가할 항목 이름을 입력해주세요 : ")
        a = input(f'{name}이(가) 맞습니까? y 이외에는 취소됩니다 : ')
        if a == 'y':
            mount = input("현재 갯수를 입력해주세요 : ")
            price = input("1개의 가격을 입력해주세요 : ")
            b = input(f'{name} 항목에 {mount}개, {price}원 맞습니까? y 이외에는 취소됩니다.: ')
            if b == 'y':
                ojall[name] = int(mount)
                ojprice[name] = int(price)
                print(f'{name} 항목 {mount}개,1개에 {price}원 추가되었습니다.\n')
            else:
                print('이전 화면으로 돌아갑니다.\n')
        else:
            print('이전 화면으로 돌아갑니다.\n')
            
    elif what == '4':
        name = input("제거할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            b = input(f'{name} 항목을 정말로 제거하시겠습니까? y 이외에는 취소됩니다.: ')
            if b == 'y':
                del ojall[name]
                del ojprice[name]
                print(f'{name} 항목 제거되었습니다.\n')
            else:
                print('이전 화면으로 돌아갑니다.\n')
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
        
    elif what == '5':
        name = input("검색 할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            mount = ojall[name]
            price = ojprice[name]
            print(f'{name}의 남은 재고 개수는 {mount}개 재고의 총 가격은 {mount*price}원입니다.\n')
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
    elif what == '6':
        print('재고 가격 순으로 정렬합니다.')
        list_ojmount = []
        list_ojmount = []
        temp1 = {}
        temp2 = {}
        for i,v in ojall.items():
            temp1[v*ojprice[i]] = i
            temp2[i] = v*ojprice[i]
            list_ojmount.append(v*ojprice[i])
        list_ojmount.sort()
        list_ojmount.reverse()
        for i in range(len(list_ojmount)):
            print('''%d.:\t%s %d개 %d원'''%(i+1,temp1[list_ojmount[i]],ojall[temp1[list_ojmount[i]]],temp2[temp1[list_ojmount[i]]]))
        print('재고의 총 가격은 %d원 입니다.\n' %sum(temp2.values()))
            
            
    elif what == '0':
        print('프로그램을 종료합니다.')
        break
        
    else:
        print("잘못 입력하셨습니다. 0 ~ 6 중 하나로 입력해주세요.\n")
        continue
# Out:
# ================================================================================
#
#                              재고관리 프로그램
#
#                             항목                갯수           가격
#
#                           과자        :      20개       :   1개 2000원
#                           커피        :      30개       :   1개 1500원
#                           아이스크림        :      23개       :   1개 1000원
#
#
# ================================================================================
# 무엇을 하시겠습니까?
#
# 1 : 재고 추가  | 2 : 재고 제거  |  3 : 항목 추가  |  4 : 항목 제거  |  5 : 재고 검색  |  6 ; 재고 현황  |   0 : 프로그램 종료
#  3
# 추가할 항목 이름을 입력해주세요 : a
# a이(가) 맞습니까? y 이외에는 취소됩니다 : y
# 현재 갯수를 입력해주세요 : 1
# 1개의 가격을 입력해주세요 : 10
# a 항목에 1개, 10원 맞습니까? y 이외에는 취소됩니다.: a
# 이전 화면으로 돌아갑니다.
#
# ================================================================================
#
#                              재고관리 프로그램
#
#                             항목                갯수           가격
#
#                           과자        :      20개       :   1개 2000원
#                           커피        :      30개       :   1개 1500원
#                           아이스크림        :      23개       :   1개 1000원
#
#
# ================================================================================

# %%
# [도전 과제] 자유주제로 프로그래밍을 수행하세요. 단 예외처리 3건 이상
ojall = {'과자' : 20 , '커피' : 30 , '아이스크림' : 23}
ojprice = {'과자' : 2000, '커피' : 1500, '아이스크림': 1000}
while 1:
    ojkey = list(ojall)
    print('='*80)
    print('''
                             재고관리 프로그램
    ''')
    print('''                            항목                갯수           가격\n''')
    for i in range(len(ojkey)):
        print(f'''                          {ojkey[i]}        :      {ojall[ojkey[i]]}개       :   1개 {ojprice[ojkey[i]]}원''')
    print('\n')
    print('='*80)
    what = input("""무엇을 하시겠습니까?  
    
1 : 재고 추가  | 2 : 재고 제거  |  3 : 항목 추가  |  4 : 항목 제거  |  5 : 재고 검색  |  6 ; 재고 현황  |   0 : 프로그램 종료     \n """  )
    if what == '1':
        name = input("재고를 추가할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            while 1:
                try:
                    mount = int(input("얼마나 추가 하시겠습니까   :   "))
                    b = input(f'{name} 항목에 {mount}개 추가가 맞습니까? y 이외에는 취소됩니다.: ')
                    if b == 'y':
                        ojall[name] += mount
                        print(f'{mount}개 추가되었습니다.\n')
                        break
                    else:
                        print('이전 화면으로 돌아갑니다.\n')
                        break
                except:
                    print("잘못 입력하셨습니다. 숫자를 입력해주세요")
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
            
    elif what == '2':
        name = input("재고를 제거할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            while 1:
                try:
                    mount = int(input("얼마나 제거 하시겠습니까   :   "))
                    b = input(f'{name} 항목에 {mount}개 제거가 맞습니까? y 이외에는 취소됩니다.: ')
                    if b == 'y':
                        ojall[name] -= mount
                        print(f'{mount}개 제거되었습니다.\n')
                        break
                    else:
                        print('이전 화면으로 돌아갑니다.\n')
                        break
                except:
                    print("숫자를 입력해주세요")
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
            
    elif what == '3':
        name = input("추가할 항목 이름을 입력해주세요 : ")
        a = input(f'{name}이(가) 맞습니까? y 이외에는 취소됩니다 : ')
        if a == 'y':
            while 1:
                try:
                    mount = int(input("현재 갯수를 입력해주세요 : "))
                    break
                except:
                    print("숫자를 입력해주세요")
            while 1:
                try:
                    price = int(input("1개의 가격을 입력해주세요 : "))
                    break
                except:
                    print("숫자를 입력해주세요")
            b = input(f'{name} 항목에 {mount}개, {price}원 맞습니까? y 이외에는 취소됩니다.: ')
            if b == 'y':
                ojall[name] = mount
                ojprice[name] = price
                print(f'{name} 항목 {mount}개,1개에 {price}원 추가되었습니다.\n')
            else:
                print('이전 화면으로 돌아갑니다.\n')
        else:
            print('이전 화면으로 돌아갑니다.\n')
            
    elif what == '4':
        name = input("제거할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            b = input(f'{name} 항목을 정말로 제거하시겠습니까? y 이외에는 취소됩니다.: ')
            if b == 'y':
                del ojall[name]
                del ojprice[name]
                print(f'{name} 항목 제거되었습니다.\n')
            else:
                print('이전 화면으로 돌아갑니다.\n')
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
        
    elif what == '5':
        name = input("검색 할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            mount = ojall[name]
            price = ojprice[name]
            print(f'{name}의 남은 재고 개수는 {mount}개 재고의 총 가격은 {mount*price}원입니다.\n')
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
    elif what == '6':
        print('재고 가격 순으로 정렬합니다.')
        list_ojmount = []
        list_ojmount = []
        temp1 = {}
        temp2 = {}
        for i,v in ojall.items():
            temp1[v*ojprice[i]] = i
            temp2[i] = v*ojprice[i]
            list_ojmount.append(v*ojprice[i])
        list_ojmount.sort()
        list_ojmount.reverse()
        for i in range(len(list_ojmount)):
            print('''%d.:\t%s %d개 %d원'''%(i+1,temp1[list_ojmount[i]],ojall[temp1[list_ojmount[i]]],temp2[temp1[list_ojmount[i]]]))
        print('재고의 총 가격은 %d원 입니다.\n' %sum(temp2.values()))
            
            
    elif what == '0':
        print('프로그램을 종료합니다.')
        break
        
    else:
        print("잘못 입력하셨습니다. 0 ~ 6 중 하나로 입력해주세요.\n")
        continue

# %%
# [과제] 관심 주제에 대하여 100~ 200라인 정도의 프로그램을 구조지향적으로 
# 작성하신 후 클래스를 이용한 객체지향 프로그래밍으로 수정하세요.(필요시 상속 이용)

ojall = {'과자' : 20 , '커피' : 30 , '아이스크림' : 23}
ojprice = {'과자' : 2000, '커피' : 1500, '아이스크림': 1000}
while 1:
    ojkey = list(ojall)
    print('='*80)
    print('''
                             재고관리 프로그램
    ''')
    print('''                            항목                갯수           가격\n''')
    for i in range(len(ojkey)):
        print(f'''                          {ojkey[i]}        :      {ojall[ojkey[i]]}개       :   1개 {ojprice[ojkey[i]]}원''')
    print('\n')
    print('='*80)
    what = input("""무엇을 하시겠습니까?  
    
1 : 재고 추가  | 2 : 재고 제거  |  3 : 항목 추가  |  4 : 항목 제거  |  5 : 재고 검색  |  6 ; 재고 현황  |   0 : 프로그램 종료     \n """  )
    if what == '1':
        name = input("재고를 추가할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            while 1:
                try:
                    mount = int(input("얼마나 추가 하시겠습니까   :   "))
                except:
                    print("잘못 입력하셨습니다. 숫자를 입력해주세요")
                else:
                    b = input(f'{name} 항목에 {mount}개 추가가 맞습니까? y 이외에는 취소됩니다.: ')
                    if b == 'y':
                        ojall[name] += mount
                        print(f'{mount}개 추가되었습니다.\n')
                        break
                    else:
                        print('이전 화면으로 돌아갑니다.\n')
                        break
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
            
    elif what == '2':
        name = input("재고를 제거할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            while 1:
                try:
                    mount = int(input("얼마나 제거 하시겠습니까   :   "))  
                except:
                    print("숫자를 입력해주세요")
                else:
                    b = input(f'{name} 항목에 {mount}개 제거가 맞습니까? y 이외에는 취소됩니다.: ')
                    if b == 'y':
                        ojall[name] -= mount
                        print(f'{mount}개 제거되었습니다.\n')
                        break
                    else:
                        print('이전 화면으로 돌아갑니다.\n')
                        break
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
            
    elif what == '3':
        name = input("추가할 항목 이름을 입력해주세요 : ")
        a = input(f'{name}이(가) 맞습니까? y 이외에는 취소됩니다 : ')
        if a == 'y':
            while 1:
                try:
                    mount = int(input("현재 갯수를 입력해주세요 : "))
                except:
                    print("숫자를 입력해주세요")
                else:
                    break
            while 1:
                try:
                    price = int(input("1개의 가격을 입력해주세요 : "))
                except:
                    print("숫자를 입력해주세요")
                else:
                    break
            b = input(f'{name} 항목에 {mount}개, {price}원 맞습니까? y 이외에는 취소됩니다.: ')
            if b == 'y':
                ojall[name] = mount
                ojprice[name] = price
                print(f'{name} 항목 {mount}개,1개에 {price}원 추가되었습니다.\n')
            else:
                print('이전 화면으로 돌아갑니다.\n')
        else:
            print('이전 화면으로 돌아갑니다.\n')
            
    elif what == '4':
        name = input("제거할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            b = input(f'{name} 항목을 정말로 제거하시겠습니까? y 이외에는 취소됩니다.: ')
            if b == 'y':
                del ojall[name]
                del ojprice[name]
                print(f'{name} 항목 제거되었습니다.\n')
            else:
                print('이전 화면으로 돌아갑니다.\n')
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
        
    elif what == '5':
        name = input("검색 할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            mount = ojall[name]
            price = ojprice[name]
            print(f'{name}의 남은 재고 개수는 {mount}개 재고의 총 가격은 {mount*price}원입니다.\n')
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
    elif what == '6':
        print('재고 가격 순으로 정렬합니다.')
        list_ojmount = []
        list_ojmount = []
        temp1 = {}
        temp2 = {}
        for i,v in ojall.items():
            temp1[v*ojprice[i]] = i
            temp2[i] = v*ojprice[i]
            list_ojmount.append(v*ojprice[i])
        list_ojmount.sort()
        list_ojmount.reverse()
        for i in range(len(list_ojmount)):
            print('''%d.:\t%s %d개 %d원'''%(i+1,temp1[list_ojmount[i]],ojall[temp1[list_ojmount[i]]],temp2[temp1[list_ojmount[i]]]))
        print('재고의 총 가격은 %d원 입니다.\n' %sum(temp2.values()))
            
            
    elif what == '0':
        print('프로그램을 종료합니다.')
        break
        
    else:
        print("잘못 입력하셨습니다. 0 ~ 6 중 하나로 입력해주세요.\n")
        continue
# Out:
# ================================================================================
#
#                              재고관리 프로그램
#
#                             항목                갯수           가격
#
#                           과자        :      20개       :   1개 2000원
#                           커피        :      30개       :   1개 1500원
#                           아이스크림        :      23개       :   1개 1000원
#
#
# ================================================================================
# 무엇을 하시겠습니까?
#
# 1 : 재고 추가  | 2 : 재고 제거  |  3 : 항목 추가  |  4 : 항목 제거  |  5 : 재고 검색  |  6 ; 재고 현황  |   0 : 프로그램 종료
#  1
# 재고를 추가할 항목 이름을 입력해주세요 :  w
# 없는 항목입니다. 이전으로 돌아갑니다.
#
# ================================================================================
#
#                              재고관리 프로그램
#
#                             항목                갯수           가격
#
#                           과자        :      20개       :   1개 2000원
#                           커피        :      30개       :   1개 1500원
#                           아이스크림        :      23개       :   1개 1000원
#
#
# ================================================================================
# 무엇을 하시겠습니까?
#
# 1 : 재고 추가  | 2 : 재고 제거  |  3 : 항목 추가  |  4 : 항목 제거  |  5 : 재고 검색  |  6 ; 재고 현황  |   0 : 프로그램 종료
#  1
# 재고를 추가할 항목 이름을 입력해주세요 : 과자
# 얼마나 추가 하시겠습니까   :   ㅁ
# 잘못 입력하셨습니다. 숫자를 입력해주세요
# 얼마나 추가 하시겠습니까   :   1
# 과자 항목에 1개 추가가 맞습니까? y 이외에는 취소됩니다.: ㄹ
# 이전 화면으로 돌아갑니다.
#
# ================================================================================
#
#                              재고관리 프로그램
#
#                             항목                갯수           가격
#
#                           과자        :      20개       :   1개 2000원
#                           커피        :      30개       :   1개 1500원
#                           아이스크림        :      23개       :   1개 1000원
#
#
# ================================================================================
# 무엇을 하시겠습니까?
#
# 1 : 재고 추가  | 2 : 재고 제거  |  3 : 항목 추가  |  4 : 항목 제거  |  5 : 재고 검색  |  6 ; 재고 현황  |   0 : 프로그램 종료
#
# 잘못 입력하셨습니다. 0 ~ 6 중 하나로 입력해주세요.
#
# ================================================================================
#
#                              재고관리 프로그램
#
#                             항목                갯수           가격
#
#                           과자        :      20개       :   1개 2000원
#                           커피        :      30개       :   1개 1500원
#                           아이스크림        :      23개       :   1개 1000원
#
#
# ================================================================================
# 무엇을 하시겠습니까?
#
# 1 : 재고 추가  | 2 : 재고 제거  |  3 : 항목 추가  |  4 : 항목 제거  |  5 : 재고 검색  |  6 ; 재고 현황  |   0 : 프로그램 종료
#  1
# 재고를 추가할 항목 이름을 입력해주세요 : 과자
# 얼마나 추가 하시겠습니까   :   1
# 과자 항목에 1개 추가가 맞습니까? y 이외에는 취소됩니다.: t
# 이전 화면으로 돌아갑니다.
#
# ================================================================================
#
#                              재고관리 프로그램
#
#                             항목                갯수           가격
#
#                           과자        :      20개       :   1개 2000원
#                           커피        :      30개       :   1개 1500원
#                           아이스크림        :      23개       :   1개 1000원
#
#
# ================================================================================
# 무엇을 하시겠습니까?
#
# 1 : 재고 추가  | 2 : 재고 제거  |  3 : 항목 추가  |  4 : 항목 제거  |  5 : 재고 검색  |  6 ; 재고 현황  |   0 : 프로그램 종료
#  1
# 재고를 추가할 항목 이름을 입력해주세요 : 과자
# 얼마나 추가 하시겠습니까   :   1
# 과자 항목에 1개 추가가 맞습니까? y 이외에는 취소됩니다.: y
# 1개 추가되었습니다.
#
# ================================================================================
#
#                              재고관리 프로그램
#
#                             항목                갯수           가격
#
#                           과자        :      21개       :   1개 2000원
#                           커피        :      30개       :   1개 1500원
#                           아이스크림        :      23개       :   1개 1000원
#
#
# ================================================================================
# 무엇을 하시겠습니까?
#
# 1 : 재고 추가  | 2 : 재고 제거  |  3 : 항목 추가  |  4 : 항목 제거  |  5 : 재고 검색  |  6 ; 재고 현황  |   0 : 프로그램 종료
#  6
# 재고 가격 순으로 정렬합니다.
# 1.:	커피 30개 45000원
# 2.:	과자 21개 42000원
# 3.:	아이스크림 23개 23000원
# 재고의 총 가격은 110000원 입니다.
#
# ================================================================================
#
#                              재고관리 프로그램
#
#                             항목                갯수           가격
#
#                           과자        :      21개       :   1개 2000원
#                           커피        :      30개       :   1개 1500원
#                           아이스크림        :      23개       :   1개 1000원
#
#
# ================================================================================
# 무엇을 하시겠습니까?
#
# 1 : 재고 추가  | 2 : 재고 제거  |  3 : 항목 추가  |  4 : 항목 제거  |  5 : 재고 검색  |  6 ; 재고 현황  |   0 : 프로그램 종료
#  0
# 프로그램을 종료합니다.

# %%
if what == '1':
name = input("재고를 추가할 항목 이름을 입력해주세요 : ")
if name in ojall:
    while 1:
        try:
            mount = int(input("얼마나 추가 하시겠습니까   :   "))
            b = input(f'{name} 항목에 {mount}개 추가가 맞습니까? y 이외에는 취소됩니다.: ')
            if b == 'y':
                ojall[name] += mount
                print(f'{mount}개 추가되었습니다.\n')
                break
            else:
                print('이전 화면으로 돌아갑니다.\n')
                break
        except:
            print("잘못 입력하셨습니다. 숫자를 입력해주세요")
else:
    print("없는 항목입니다. 이전으로 돌아갑니다.\n")

# %%
class Jego:
    def __init__(self):
        self.ojall = {'과자' : 20 , '커피' : 30 , '아이스크림' : 23}
        self.ojprice = {'과자' : 2000, '커피' : 1500, '아이스크림': 1000}
    def jegoshow(self):
        ojkey = list(self.ojall)
        print('='*80)
        print('''
                                 재고관리 프로그램
        ''')
        print('''                            항목                갯수           가격\n''')
        for i in range(len(ojkey)):
            print(f'''                          {ojkey[i]}        :      {ojall[ojkey[i]]}개       :   1개 {ojprice[ojkey[i]]}원''')
        print('\n')
        print('='*80)
    def jegoadd(self):
        global ojall
        name = input("재고를 추가할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            while 1:
                try:
                    mount = int(input("얼마나 추가 하시겠습니까   :   "))
                except:
                    print("잘못 입력하셨습니다. 숫자를 입력해주세요")
                else:
                    b = input(f'{name} 항목에 {mount}개 추가가 맞습니까? y 이외에는 취소됩니다.: ')
                    if b == 'y':
                        ojall[name] += mount
                        print(f'{mount}개 추가되었습니다.\n')
                        break
                    else:
                        print('이전 화면으로 돌아갑니다.\n')
                        break
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
            
    def jegosub(self):
        global ojall
        name = input("재고를 제거할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            while 1:
                try:
                    mount = int(input("얼마나 제거 하시겠습니까   :   "))  
                except:
                    print("숫자를 입력해주세요")
                else:
                    b = input(f'{name} 항목에 {mount}개 제거가 맞습니까? y 이외에는 취소됩니다.: ')
                    if b == 'y':
                        ojall[name] -= mount
                        print(f'{mount}개 제거되었습니다.\n')
                        break
                    else:
                        print('이전 화면으로 돌아갑니다.\n')
                        break
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
            
    def jegonew(self):
        name = input("추가할 항목 이름을 입력해주세요 : ")
        a = input(f'{name}이(가) 맞습니까? y 이외에는 취소됩니다 : ')
        if a == 'y':
            while 1:
                try:
                    mount = int(input("현재 갯수를 입력해주세요 : "))
                except:
                    print("숫자를 입력해주세요")
                else:
                    break
            while 1:
                try:
                    price = int(input("1개의 가격을 입력해주세요 : "))
                except:
                    print("숫자를 입력해주세요")
                else:
                    break
            b = input(f'{name} 항목에 {mount}개, {price}원 맞습니까? y 이외에는 취소됩니다.: ')
            if b == 'y':
                ojall[name] = mount
                ojprice[name] = price
                print(f'{name} 항목 {mount}개,1개에 {price}원 추가되었습니다.\n')
            else:
                print('이전 화면으로 돌아갑니다.\n')
        else:
            print('이전 화면으로 돌아갑니다.\n')
            
    def jegodel(self):
        ame = input("제거할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            b = input(f'{name} 항목을 정말로 제거하시겠습니까? y 이외에는 취소됩니다.: ')
            if b == 'y':
                del ojall[name]
                del ojprice[name]
                print(f'{name} 항목 제거되었습니다.\n')
            else:
                print('이전 화면으로 돌아갑니다.\n')
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
            
    def jegosearch(self):
        name = input("검색 할 항목 이름을 입력해주세요 : ")
        if name in ojall:
            mount = ojall[name]
            price = ojprice[name]
            print(f'{name}의 남은 재고 개수는 {mount}개 재고의 총 가격은 {mount*price}원입니다.\n')
        else:
            print("없는 항목입니다. 이전으로 돌아갑니다.\n")
    
    def jegonow(self):
        print('재고 가격 순으로 정렬합니다.')
        list_ojmount = []
        list_ojmount = []
        temp1 = {}
        temp2 = {}
        for i,v in ojall.items():
            temp1[v*ojprice[i]] = i
            temp2[i] = v*ojprice[i]
            list_ojmount.append(v*ojprice[i])
        list_ojmount.sort()
        list_ojmount.reverse()
        for i in range(len(list_ojmount)):
            print('''%d.:\t%s %d개 %d원'''%(i+1,temp1[list_ojmount[i]],ojall[temp1[list_ojmount[i]]],temp2[temp1[list_ojmount[i]]]))
        print('재고의 총 가격은 %d원 입니다.\n' %sum(temp2.values()))
